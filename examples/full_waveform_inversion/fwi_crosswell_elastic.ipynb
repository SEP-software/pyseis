# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage

from pyseis.wave_equations import elastic_isotropic
from pyseis.wavelets.elastic import Elastic2D
from pyseis import inversion

import sys
sys.path.append("../")
import plotting
# Out:
# WARNING! DATAPATH not found. The folder /tmp will be used to write binary files

# %% [markdown]
# ## Helper functions

# %%
def make_random_ela_model(shape,seed=113,vs_min=600,vs_trend=0.32,v_s_var=1000, vp_vs_ratio=1.8):
    n_x, n_z = shape
    np.random.seed(seed)

    v_s = vs_min + vs_trend * np.arange(n_z) + v_s_var * (np.random.rand(n_z) - 0.5)
    v_s = ndimage.gaussian_filter(v_s,1,mode='nearest')
    v_s = np.pad(np.expand_dims(v_s,axis=0),((n_x-1,0),(0,0)),mode='edge')

    v_p = v_s * vp_vs_ratio
    rho = 310 * v_p**0.25
    
    return np.concatenate([np.expand_dims(v_p,axis=0),
                           np.expand_dims(v_s,axis=0),
                           np.expand_dims(rho,axis=0)],axis=0)
    
def myround(x, base=5):
    return (base * (np.array(x) / base).round())

# %% [markdown]
# ## Make "random" 1.5d model and src/rec geometry

# %%
n_x, n_z = 100, 140
d_x = d_z = 10.0
o_x, o_z = 0.0, 1000.0

#create model
ela_model = make_random_ela_model((n_x,n_z),vs_min=2000,vp_vs_ratio=1.1,vs_trend=8)
ela_model[ela_model<1900.0] = 1900.0

plt.figure(figsize=(5,10))
labels = ['$v_s$ (m/s)','$v_s$ (m/s)','density (kg/$m^3$)']
for model, label in zip(ela_model, labels):
    plt.plot(model[0],o_z + d_z * np.arange(n_z),label=label)
plt.legend()
plt.grid()
plt.gca().invert_yaxis()
_ = plt.ylabel('depth (m)')
_ = plt.xlabel('parameter value')

# %%
# create source and receiver geometry
rec_top_depth = 1200.0
rec_bot_depth = 1800.0
rec_spacing = 5.0
rec_x_pos = 700.0
z_rec = np.arange(rec_top_depth,rec_bot_depth+rec_spacing,rec_spacing)
x_rec = rec_x_pos * np.ones_like(z_rec) 
recs = np.array([x_rec, z_rec]).T

src_top_depth = 1200.0
src_bot_depth = 1800.0
src_spacing = 25.0
src_x_pos = 300.0
z_src = np.arange(src_top_depth,src_bot_depth+src_spacing,src_spacing)
x_src = src_x_pos * np.ones_like(z_src) 
srcs = np.array([x_src, z_src]).T

#plot 
plotting.plot_model(ela_model[0],
                   title='1.5d model', 
                   cbar=True,
                   sampling=(d_x,d_z),
                   origins = (o_x,o_z),
                   cmap='viridis',
                   src_locations=srcs,
                   rec_locations=recs,
                   figsize=(8,6))

# %%
# make an explosive Trapezoid wavelet
n_t = 1000
d_t = 0.001
f_1 = 5 # 30.0
f_2 = 10 # 150.0
f_3 = 30 # 250.0
f_4 = 45 # 350.0
delay = 0.25
wavelets = Elastic2D.ElasticIsotropicTrapezoid2D(n_t, d_t, f_1, f_2, f_3, f_4, delay).arr
scale=1e10 
wavelets*=scale

plotting.plot_wavelet(wavelets[2],d_t,title='ricker wavelet')

# %%
# make 2d acoustic wave equation solver
elastic_2d = elastic_isotropic.ElasticIsotropic2D(
  model=ela_model,
  model_sampling=(d_x, d_z),
  model_origins=(o_x, o_z),
  model_padding=(50, 50),
  wavelet=wavelets,
  d_t=d_t,
  src_locations=srcs,
  rec_locations=recs,
  gpus=[0,1,2,3],
  recording_components=['vx','vz'],
subsampling=5)

# %%
# %%time
data_obs = elastic_2d.forward(ela_model)

plotting.plot_data(data_obs[:,1],
                   d_t,
                   n_shots=2,
                   src_locations=z_src,
                   rec_locations=z_rec,
                   pclip=98,
                   figsize=(10, 10),)
# Out:
# CPU times: user 33 s, sys: 2.15 s, total: 35.1 s
# Wall time: 4.2 s

# %% [markdown]
# ## make FWI starting model

# %%
starting_model = ndimage.gaussian_filter(ela_model, (0, 50, 50), mode='nearest')

plotting.plot_model(starting_model[0],
                   title='1.5d model', 
                   cbar=True,
                   sampling=(d_x,d_z),
                   origins = (o_x,o_z),
                   cmap='viridis',
                   src_locations=srcs,
                   rec_locations=recs,
                   figsize=(8,6))

# %%
plt.figure(figsize=(5,10))
labels = ['$v_s$ (m/s)','$v_s$ (m/s)','density (kg/$m^3$)']
colors = ['r','g','b']
for model, start_mod, label, color in zip(ela_model, starting_model, labels, colors):
    plt.plot(model[0],o_z + d_z * np.arange(n_z),label=label, color=color)
    plt.plot(start_mod[0],o_z + d_z * np.arange(n_z), color=color,linestyle='--')
plt.legend()
plt.grid()
plt.gca().invert_yaxis()
_ = plt.ylabel('depth (m)')
_ = plt.xlabel('parameter value')

# %% [markdown]
# ## Make a gradient mask

# %%
# mask of 1.0's the size of the elastic model
gradient_mask = np.ones_like(ela_model)

# make mask zero to the left of srcs and right of receivers
x_buffer = 50.0
for i_x in range(n_x):
    x = o_x + i_x * d_x
    if x <= src_x_pos + x_buffer or x >= rec_x_pos - x_buffer:
        gradient_mask[:,i_x,:] *= 0.0

# scale with depth
gradient_mask *= np.arange(n_z)/n_z      

# smooth
gradient_mask = ndimage.gaussian_filter(gradient_mask,(0,2,2))

# plot
plotting.plot_model(gradient_mask[0],
                   title='$v_p$ gradient mask',
                   cbar=True,
                   sampling=(d_x,d_z),
                    origins=(o_x,o_z),
                   cmap='jet',
                   src_locations=srcs,
                   rec_locations=recs,
                   figsize=(8,6),
                   vlims=[0,1])

# %%
# !rm /tmp/*.H@
# !rm wrk/crosswell_ela*

# %%
fwi_prob = inversion.Fwi(elastic_2d,
                         data_obs,
                         starting_model,
                         solver_type='nlcg',
                         num_iter=100,
                         iterations_per_save=10,
                         prefix='crosswell_ela',
                         # model_bounds=[1500.0,4500.0],
                         gradient_mask = gradient_mask)

# %%
# %%time

history = fwi_prob.run()
# Out:
# ##########################################################################################
# 			NON-LINEAR CONJUGATE GRADIENT SOLVER
# 	Restart folder: /tmp/restart_2023-02-13T23-05-03.069908/
# 	Conjugate method used: FR
# ##########################################################################################
#
# iter = 000, obj = 2.79541e-04, resnorm = 2.36e-02, gradnorm = 9.84e-09, feval = 1, geval = 1
# iter = 001, obj = 2.09971e-04, resnorm = 2.05e-02, gradnorm = 1.11e-08, feval = 4, geval = 2
# iter = 002, obj = 1.77195e-04, resnorm = 1.88e-02, gradnorm = 1.44e-08, feval = 9, geval = 3
# iter = 003, obj = 1.55233e-04, resnorm = 1.76e-02, gradnorm = 1.43e-08, feval = 12, geval = 4
# iter = 004, obj = 1.19199e-04, resnorm = 1.54e-02, gradnorm = 1.20e-08, feval = 15, geval = 5
# iter = 005, obj = 1.04584e-04, resnorm = 1.45e-02, gradnorm = 9.90e-09, feval = 18, geval = 6
# iter = 006, obj = 9.24107e-05, resnorm = 1.36e-02, gradnorm = 7.71e-09, feval = 21, geval = 7
# iter = 007, obj = 8.21589e-05, resnorm = 1.28e-02, gradnorm = 6.99e-09, feval = 24, geval = 8
# iter = 008, obj = 7.33015e-05, resnorm = 1.21e-02, gradnorm = 6.47e-09, feval = 27, geval = 9
# iter = 009, obj = 6.50106e-05, resnorm = 1.14e-02, gradnorm = 4.98e-09, feval = 30, geval = 10
# iter = 010, obj = 5.78369e-05, resnorm = 1.08e-02, gradnorm = 5.39e-09, feval = 33, geval = 11
# iter = 011, obj = 5.35102e-05, resnorm = 1.03e-02, gradnorm = 5.80e-09, feval = 36, geval = 12
# iter = 012, obj = 4.97443e-05, resnorm = 9.97e-03, gradnorm = 4.93e-09, feval = 39, geval = 13
# iter = 013, obj = 4.59138e-05, resnorm = 9.58e-03, gradnorm = 3.76e-09, feval = 42, geval = 14
# iter = 014, obj = 4.19516e-05, resnorm = 9.16e-03, gradnorm = 3.44e-09, feval = 45, geval = 15
# iter = 015, obj = 3.85766e-05, resnorm = 8.78e-03, gradnorm = 3.37e-09, feval = 48, geval = 16
# iter = 016, obj = 3.60735e-05, resnorm = 8.49e-03, gradnorm = 2.87e-09, feval = 51, geval = 17
# iter = 017, obj = 3.38733e-05, resnorm = 8.23e-03, gradnorm = 2.76e-09, feval = 54, geval = 18
# iter = 018, obj = 3.19956e-05, resnorm = 8.00e-03, gradnorm = 2.92e-09, feval = 57, geval = 19
# iter = 019, obj = 3.05481e-05, resnorm = 7.82e-03, gradnorm = 2.74e-09, feval = 60, geval = 20
# iter = 020, obj = 2.92438e-05, resnorm = 7.65e-03, gradnorm = 2.32e-09, feval = 63, geval = 21
# iter = 021, obj = 2.79025e-05, resnorm = 7.47e-03, gradnorm = 2.19e-09, feval = 66, geval = 22
# iter = 022, obj = 2.67180e-05, resnorm = 7.31e-03, gradnorm = 2.32e-09, feval = 69, geval = 23
# iter = 023, obj = 2.53899e-05, resnorm = 7.13e-03, gradnorm = 2.37e-09, feval = 72, geval = 24
# iter = 024, obj = 2.43042e-05, resnorm = 6.97e-03, gradnorm = 2.25e-09, feval = 75, geval = 25
# iter = 025, obj = 2.33927e-05, resnorm = 6.84e-03, gradnorm = 2.22e-09, feval = 78, geval = 26
# iter = 026, obj = 2.24403e-05, resnorm = 6.70e-03, gradnorm = 1.99e-09, feval = 81, geval = 27
# iter = 027, obj = 2.13797e-05, resnorm = 6.54e-03, gradnorm = 1.87e-09, feval = 84, geval = 28
# iter = 028, obj = 2.04416e-05, resnorm = 6.39e-03, gradnorm = 1.86e-09, feval = 87, geval = 29
# iter = 029, obj = 1.97399e-05, resnorm = 6.28e-03, gradnorm = 1.86e-09, feval = 90, geval = 30
# iter = 030, obj = 1.89560e-05, resnorm = 6.16e-03, gradnorm = 1.68e-09, feval = 93, geval = 31
# iter = 031, obj = 1.82376e-05, resnorm = 6.04e-03, gradnorm = 1.47e-09, feval = 96, geval = 32
# iter = 032, obj = 1.76256e-05, resnorm = 5.94e-03, gradnorm = 1.57e-09, feval = 99, geval = 33
# iter = 033, obj = 1.71050e-05, resnorm = 5.85e-03, gradnorm = 1.65e-09, feval = 102, geval = 34
# iter = 034, obj = 1.65712e-05, resnorm = 5.76e-03, gradnorm = 1.45e-09, feval = 105, geval = 35
# iter = 035, obj = 1.61142e-05, resnorm = 5.68e-03, gradnorm = 1.29e-09, feval = 108, geval = 36
# iter = 036, obj = 1.55628e-05, resnorm = 5.58e-03, gradnorm = 1.43e-09, feval = 111, geval = 37
# iter = 037, obj = 1.50586e-05, resnorm = 5.49e-03, gradnorm = 1.38e-09, feval = 114, geval = 38
# iter = 038, obj = 1.46653e-05, resnorm = 5.42e-03, gradnorm = 1.40e-09, feval = 117, geval = 39
# iter = 039, obj = 1.42783e-05, resnorm = 5.34e-03, gradnorm = 1.40e-09, feval = 120, geval = 40
# iter = 040, obj = 1.38730e-05, resnorm = 5.27e-03, gradnorm = 1.22e-09, feval = 123, geval = 41
# iter = 041, obj = 1.34168e-05, resnorm = 5.18e-03, gradnorm = 1.33e-09, feval = 126, geval = 42
# iter = 042, obj = 1.29201e-05, resnorm = 5.08e-03, gradnorm = 1.38e-09, feval = 129, geval = 43
# iter = 043, obj = 1.25197e-05, resnorm = 5.00e-03, gradnorm = 1.31e-09, feval = 132, geval = 44
# iter = 044, obj = 1.21332e-05, resnorm = 4.93e-03, gradnorm = 1.14e-09, feval = 135, geval = 45
# iter = 045, obj = 1.18550e-05, resnorm = 4.87e-03, gradnorm = 1.05e-09, feval = 138, geval = 46
# iter = 046, obj = 1.15827e-05, resnorm = 4.81e-03, gradnorm = 1.15e-09, feval = 141, geval = 47
# iter = 047, obj = 1.12502e-05, resnorm = 4.74e-03, gradnorm = 1.06e-09, feval = 144, geval = 48
# iter = 048, obj = 1.09923e-05, resnorm = 4.69e-03, gradnorm = 1.04e-09, feval = 147, geval = 49
# iter = 049, obj = 1.06790e-05, resnorm = 4.62e-03, gradnorm = 1.14e-09, feval = 150, geval = 50
# iter = 050, obj = 1.03831e-05, resnorm = 4.56e-03, gradnorm = 1.10e-09, feval = 153, geval = 51
# iter = 051, obj = 1.01446e-05, resnorm = 4.50e-03, gradnorm = 1.08e-09, feval = 156, geval = 52
# iter = 052, obj = 9.90419e-06, resnorm = 4.45e-03, gradnorm = 9.90e-10, feval = 159, geval = 53
# iter = 053, obj = 9.65493e-06, resnorm = 4.39e-03, gradnorm = 1.00e-09, feval = 162, geval = 54
# iter = 054, obj = 9.39694e-06, resnorm = 4.34e-03, gradnorm = 9.50e-10, feval = 165, geval = 55
# iter = 055, obj = 9.21341e-06, resnorm = 4.29e-03, gradnorm = 9.00e-10, feval = 168, geval = 56
# iter = 056, obj = 9.04099e-06, resnorm = 4.25e-03, gradnorm = 8.99e-10, feval = 171, geval = 57
# iter = 057, obj = 8.83324e-06, resnorm = 4.20e-03, gradnorm = 8.28e-10, feval = 174, geval = 58
# iter = 058, obj = 8.62404e-06, resnorm = 4.15e-03, gradnorm = 8.87e-10, feval = 177, geval = 59
# iter = 059, obj = 8.43322e-06, resnorm = 4.11e-03, gradnorm = 9.29e-10, feval = 180, geval = 60
# iter = 060, obj = 8.25420e-06, resnorm = 4.06e-03, gradnorm = 8.76e-10, feval = 183, geval = 61
# iter = 061, obj = 8.07191e-06, resnorm = 4.02e-03, gradnorm = 8.87e-10, feval = 186, geval = 62
# iter = 062, obj = 7.89974e-06, resnorm = 3.97e-03, gradnorm = 8.49e-10, feval = 189, geval = 63
# iter = 063, obj = 7.74989e-06, resnorm = 3.94e-03, gradnorm = 7.72e-10, feval = 192, geval = 64
# iter = 064, obj = 7.59159e-06, resnorm = 3.90e-03, gradnorm = 7.51e-10, feval = 195, geval = 65
# iter = 065, obj = 7.45444e-06, resnorm = 3.86e-03, gradnorm = 7.59e-10, feval = 198, geval = 66
# iter = 066, obj = 7.32906e-06, resnorm = 3.83e-03, gradnorm = 7.86e-10, feval = 201, geval = 67
# iter = 067, obj = 7.18071e-06, resnorm = 3.79e-03, gradnorm = 7.72e-10, feval = 204, geval = 68
# iter = 068, obj = 7.05225e-06, resnorm = 3.76e-03, gradnorm = 7.31e-10, feval = 207, geval = 69
# iter = 069, obj = 6.93017e-06, resnorm = 3.72e-03, gradnorm = 7.32e-10, feval = 210, geval = 70
# iter = 070, obj = 6.79530e-06, resnorm = 3.69e-03, gradnorm = 7.29e-10, feval = 213, geval = 71
# iter = 071, obj = 6.67245e-06, resnorm = 3.65e-03, gradnorm = 7.28e-10, feval = 216, geval = 72
# iter = 072, obj = 6.56030e-06, resnorm = 3.62e-03, gradnorm = 6.94e-10, feval = 219, geval = 73
# iter = 073, obj = 6.45908e-06, resnorm = 3.59e-03, gradnorm = 6.51e-10, feval = 222, geval = 74
# iter = 074, obj = 6.35343e-06, resnorm = 3.56e-03, gradnorm = 6.66e-10, feval = 225, geval = 75
# iter = 075, obj = 6.24257e-06, resnorm = 3.53e-03, gradnorm = 6.41e-10, feval = 228, geval = 76
# iter = 076, obj = 6.15157e-06, resnorm = 3.51e-03, gradnorm = 6.04e-10, feval = 231, geval = 77
# iter = 077, obj = 6.05934e-06, resnorm = 3.48e-03, gradnorm = 6.23e-10, feval = 234, geval = 78
# iter = 078, obj = 5.95613e-06, resnorm = 3.45e-03, gradnorm = 6.50e-10, feval = 237, geval = 79
# iter = 079, obj = 5.86816e-06, resnorm = 3.43e-03, gradnorm = 6.44e-10, feval = 240, geval = 80
# iter = 080, obj = 5.78905e-06, resnorm = 3.40e-03, gradnorm = 6.12e-10, feval = 243, geval = 81
# iter = 081, obj = 5.70685e-06, resnorm = 3.38e-03, gradnorm = 5.89e-10, feval = 246, geval = 82
# iter = 082, obj = 5.62269e-06, resnorm = 3.35e-03, gradnorm = 5.98e-10, feval = 249, geval = 83
# iter = 083, obj = 5.54165e-06, resnorm = 3.33e-03, gradnorm = 6.17e-10, feval = 252, geval = 84
# iter = 084, obj = 5.46455e-06, resnorm = 3.31e-03, gradnorm = 6.52e-10, feval = 255, geval = 85
# iter = 085, obj = 5.38675e-06, resnorm = 3.28e-03, gradnorm = 6.62e-10, feval = 258, geval = 86
# iter = 086, obj = 5.30673e-06, resnorm = 3.26e-03, gradnorm = 6.10e-10, feval = 261, geval = 87
# iter = 087, obj = 5.23282e-06, resnorm = 3.24e-03, gradnorm = 5.81e-10, feval = 264, geval = 88
# iter = 088, obj = 5.16615e-06, resnorm = 3.21e-03, gradnorm = 5.87e-10, feval = 267, geval = 89
# iter = 089, obj = 5.10424e-06, resnorm = 3.20e-03, gradnorm = 5.29e-10, feval = 270, geval = 90
# iter = 090, obj = 5.04731e-06, resnorm = 3.18e-03, gradnorm = 4.90e-10, feval = 273, geval = 91
# iter = 091, obj = 4.99074e-06, resnorm = 3.16e-03, gradnorm = 5.33e-10, feval = 276, geval = 92
# iter = 092, obj = 4.94026e-06, resnorm = 3.14e-03, gradnorm = 5.41e-10, feval = 279, geval = 93
# iter = 093, obj = 4.89276e-06, resnorm = 3.13e-03, gradnorm = 5.02e-10, feval = 282, geval = 94
# iter = 094, obj = 4.84217e-06, resnorm = 3.11e-03, gradnorm = 4.88e-10, feval = 285, geval = 95
# iter = 095, obj = 4.79185e-06, resnorm = 3.10e-03, gradnorm = 4.89e-10, feval = 288, geval = 96
# iter = 096, obj = 4.74634e-06, resnorm = 3.08e-03, gradnorm = 4.86e-10, feval = 291, geval = 97
# iter = 097, obj = 4.69778e-06, resnorm = 3.07e-03, gradnorm = 5.03e-10, feval = 294, geval = 98
# iter = 098, obj = 4.64745e-06, resnorm = 3.05e-03, gradnorm = 5.22e-10, feval = 297, geval = 99
# iter = 099, obj = 4.59880e-06, resnorm = 3.03e-03, gradnorm = 5.14e-10, feval = 300, geval = 100
# iter = 100, obj = 4.54964e-06, resnorm = 3.02e-03, gradnorm = 4.93e-10, feval = 303, geval = 101
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# 			NON-LINEAR CONJUGATE GRADIENT SOLVER end
# ##########################################################################################
#
# CPU times: user 5h 11min 26s, sys: 21min 8s, total: 5h 32min 34s
# Wall time: 32min 37s

# %% [markdown]
# ## Plot objective function as a function of iteration

# %%
obj_func = history['obj']

fig, ax = plt.subplots(1,figsize=(10,5))
ax.plot(obj_func/obj_func.max())
_ = ax.set_xlabel('iterations')
_ = ax.set_ylabel('norm objective function')
_ = ax.set_xticks(np.arange(len(obj_func)))
ax.grid()

# %% [markdown]
# ## Plot inverted model and difference w.r.t. starting model

# %%
plotting.plot_model(history['inv_mod'][0],
                   title='Final inverted $v_p$ model',
                   cbar=True,
                   sampling=(d_x,d_z),
                   origins=(o_x,o_z),
                   cmap='viridis',
                   src_locations=srcs,
                   rec_locations=recs,
                   figsize=(8,6))

plotting.plot_model(history['inv_mod'][0]-starting_model[0],
           title='Inverted model minus starting $v_p$ model',
           cbar=True,
           cbar_label='$\Delta v_p$',
           sampling=(d_x,d_z),
           origins=(o_x,o_z),
           cmap='viridis',
           src_locations=srcs,
           rec_locations=recs,
           figsize=(8,6),
           vlims=[-500,500])

# %%
plt.figure(figsize=(5,10))
labels = ['$v_s$ (m/s)','$v_s$ (m/s)','density (kg/$m^3$)']
colors = ['r','g','b']
for model, start_mod, inv_model, label, color in zip(ela_model, starting_model, history['inv_mod'], labels, colors):
    plt.plot(model[n_x//2],o_z + d_z * np.arange(n_z),label=f'{label} true', color=color)
    plt.plot(start_mod[n_x//2],o_z + d_z * np.arange(n_z),label=f'{label} start', color=color,linestyle='--')
    plt.plot(inv_model[n_x//2],o_z + d_z * np.arange(n_z),label=f'{label} final', color=color,linestyle='dashdot')
plt.legend()
plt.grid()
plt.gca().invert_yaxis()
_ = plt.ylabel('depth (m)')
_ = plt.xlabel('parameter value')

# %%
history['residual'].shape
# Out:
# (11, 25, 2, 121, 1000)

# %%
component = 1
clip = np.percentile(np.abs(data_obs[:,component]),99)

#observed data residual
plotting.plot_data(data_obs[:,component],
          d_t,
          src_locations=z_src,
          rec_locations=z_rec,
          clip=clip,
          title='true data')

initial_data = elastic_2d.forward(starting_model)
# final residual
plotting.plot_data(initial_data[:,component],
          d_t,
          src_locations=z_src,
          rec_locations=z_rec,
          clip=clip,
          title='initial modeled data')

final_data = elastic_2d.forward(history['inv_mod'])
# final residual
plotting.plot_data(final_data[:,component],
          d_t,
          src_locations=z_src,
          rec_locations=z_rec,
          clip=clip,
          title='final modeled data')

# %% [markdown]
# ## Compare first and last FWI residuals

# %%
component = 1
clip = np.percentile(np.abs(history['residual'][:,:,component]),99)

#first residual
first_residual = history['residual'][0]
plotting.plot_data(first_residual[:,component],
          d_t,
          src_locations=z_src,
          rec_locations=z_rec,
          clip=clip)

# final residual
final_residual = history['residual'][-1]
plotting.plot_data(final_residual[:,component],
          d_t,
          src_locations=z_src,
          rec_locations=z_rec,
          clip=clip)

# %% [markdown]
# # To load previous results you can load the history dictionary with the cells below

# %%
history_load = inversion.load_history('wrk', 'crosswell_ela')

# %%
obj_func = history_load['obj']

fig, ax = plt.subplots(1,figsize=(10,5))
ax.plot(obj_func/obj_func.max())
_ = ax.set_xlabel('iterations')
_ = ax.set_ylabel('norm objective function')
_ = ax.set_xticks(np.arange(len(obj_func)))
ax.grid()
