# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage

from pyseis.wave_equations import acoustic_isotropic
from pyseis.wavelets.acoustic import Acoustic2D
from pyseis import inversion
import plotting
# Out:
# WARNING! DATAPATH not found. The folder /tmp will be used to write binary files

# %% [markdown]
# ## Helper functions

# %%
def make_random_model(shape,seed=112,min_vel=2000,max_vel=3000):
    n_x, n_z = shape
    np.random.seed(seed)

    v_p = min_vel + (max_vel-min_vel) * np.random.rand(n_z)
    v_p = ndimage.gaussian_filter(v_p,1)
    v_p = myround(v_p,10)
    
    return np.ones((n_x,n_z)) * v_p
    
def myround(x, base=5):
    return (base * (np.array(x) / base).round())

# %% [markdown]
# ## Make "random" 1.5d model and src/rec geometry

# %%
n_x = n_z = 150
d_x = d_z = 10.0

#create model
true_model = make_random_model((n_x,n_z))

# create source and receiver geometry
rec_top_depth = 400.0
rec_bot_depth = 1200.0
rec_spacing = 10.0
rec_x_pos = 1200.0
z_rec = np.arange(rec_top_depth,rec_bot_depth,rec_spacing)
x_rec = rec_x_pos * np.ones_like(z_rec) 
recs = np.array([x_rec, z_rec]).T

src_top_depth = 400.0
src_bot_depth = 1200.0
src_spacing = 25.0
src_x_pos = 400.0
z_src = np.arange(src_top_depth,src_bot_depth,src_spacing)
x_src = src_x_pos * np.ones_like(z_src) 
srcs = np.array([x_src, z_src]).T

#plot 
plotting.plot_model(true_model,
                   title='1.5d model', 
                   cbar=True,
                   sampling=(d_x,d_z),
                   cmap='viridis',
                   src_locations=srcs,
                   rec_locations=recs,
                   figsize=(8,6))

# %%
# make a Ricker wavelet
n_t = 200
d_t = 0.008
dom_freq = 20.0
delay = 0.25
ricker = Acoustic2D.AcousticIsotropicRicker2D(n_t, d_t, dom_freq, delay).arr

plotting.plot_wavelet(ricker,d_t,title='ricker wavelet')

# %%
# make 2d acoustic wave equation solver
acoustic_2d = acoustic_isotropic.AcousticIsotropic2D(
  model=true_model,
  model_sampling=(d_x,d_z),
  model_padding=(50, 50),
  wavelet=ricker,
  d_t=d_t,
  src_locations=srcs,
  rec_locations=recs,
  gpus=[0,1,2,3])

# %%
# %%time
data_obs = acoustic_2d.forward(true_model)

plotting.plot_data(data_obs,
          d_t,
          src_locations=z_src,
          rec_locations=z_rec,
          pclip=100)
# Out:
# CPU times: user 1.51 s, sys: 1.06 s, total: 2.57 s
# Wall time: 1.39 s

# %% [markdown]
# ## make FWI starting model

# %%
starting_model = np.ones(true_model.shape) * np.mean(true_model)

plotting.plot_model(starting_model,
                   title='1.5d model', 
                   cbar=True,
                   sampling=(d_x,d_z),
                   cmap='viridis',
                   src_locations=srcs,
                   rec_locations=recs,
                   figsize=(8,6))

# %%
fwi_prob = inversion.Fwi(acoustic_2d,
                         data_obs,
                         starting_model,
                         num_iter=50,
                         iterations_per_save=5,
                        prefix='crosswell')

# %%
# %%time

history = fwi_prob.run()
# Out:
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2023-01-25T22-35-59.858953/
# ##########################################################################################
#
# iter = 00, obj = 3.36876e+04, resnorm = 2.60e+02, gradnorm = 3.07e+00, feval = 1, geval = 1
# iter = 01, obj = 1.59735e+04, resnorm = 1.79e+02, gradnorm = 1.92e+00, feval = 4, geval = 2
# iter = 02, obj = 1.06394e+04, resnorm = 1.46e+02, gradnorm = 1.87e+00, feval = 7, geval = 3
# iter = 03, obj = 6.81554e+03, resnorm = 1.17e+02, gradnorm = 1.23e+00, feval = 10, geval = 4
# iter = 04, obj = 4.62217e+03, resnorm = 9.61e+01, gradnorm = 1.01e+00, feval = 13, geval = 5
# iter = 05, obj = 2.61195e+03, resnorm = 7.23e+01, gradnorm = 8.15e-01, feval = 16, geval = 6
# iter = 06, obj = 1.60834e+03, resnorm = 5.67e+01, gradnorm = 5.77e-01, feval = 19, geval = 7
# iter = 07, obj = 1.02545e+03, resnorm = 4.53e+01, gradnorm = 4.91e-01, feval = 22, geval = 8
# iter = 08, obj = 7.58643e+02, resnorm = 3.90e+01, gradnorm = 3.23e-01, feval = 25, geval = 9
# iter = 09, obj = 6.04007e+02, resnorm = 3.48e+01, gradnorm = 2.54e-01, feval = 28, geval = 10
# iter = 10, obj = 5.06724e+02, resnorm = 3.18e+01, gradnorm = 1.99e-01, feval = 31, geval = 11
# iter = 11, obj = 4.18515e+02, resnorm = 2.89e+01, gradnorm = 2.09e-01, feval = 34, geval = 12
# iter = 12, obj = 3.59693e+02, resnorm = 2.68e+01, gradnorm = 1.74e-01, feval = 37, geval = 13
# iter = 13, obj = 3.02619e+02, resnorm = 2.46e+01, gradnorm = 1.11e-01, feval = 40, geval = 14
# iter = 14, obj = 2.47690e+02, resnorm = 2.23e+01, gradnorm = 1.03e-01, feval = 43, geval = 15
# iter = 15, obj = 2.17347e+02, resnorm = 2.08e+01, gradnorm = 8.39e-02, feval = 46, geval = 16
# iter = 16, obj = 1.88069e+02, resnorm = 1.94e+01, gradnorm = 8.18e-02, feval = 49, geval = 17
# iter = 17, obj = 1.66565e+02, resnorm = 1.83e+01, gradnorm = 9.15e-02, feval = 52, geval = 18
# iter = 18, obj = 1.49153e+02, resnorm = 1.73e+01, gradnorm = 6.59e-02, feval = 55, geval = 19
# iter = 19, obj = 1.34827e+02, resnorm = 1.64e+01, gradnorm = 6.38e-02, feval = 58, geval = 20
# iter = 20, obj = 1.22673e+02, resnorm = 1.57e+01, gradnorm = 5.51e-02, feval = 61, geval = 21
# iter = 21, obj = 1.14100e+02, resnorm = 1.51e+01, gradnorm = 4.97e-02, feval = 64, geval = 22
# iter = 22, obj = 1.05771e+02, resnorm = 1.45e+01, gradnorm = 4.44e-02, feval = 67, geval = 23
# iter = 23, obj = 9.88023e+01, resnorm = 1.41e+01, gradnorm = 3.99e-02, feval = 70, geval = 24
# iter = 24, obj = 9.27077e+01, resnorm = 1.36e+01, gradnorm = 3.93e-02, feval = 73, geval = 25
# iter = 25, obj = 8.74463e+01, resnorm = 1.32e+01, gradnorm = 3.17e-02, feval = 76, geval = 26
# iter = 26, obj = 8.29464e+01, resnorm = 1.29e+01, gradnorm = 2.75e-02, feval = 79, geval = 27
# iter = 27, obj = 7.86048e+01, resnorm = 1.25e+01, gradnorm = 2.95e-02, feval = 82, geval = 28
# iter = 28, obj = 7.45910e+01, resnorm = 1.22e+01, gradnorm = 3.06e-02, feval = 85, geval = 29
# iter = 29, obj = 7.15352e+01, resnorm = 1.20e+01, gradnorm = 2.76e-02, feval = 88, geval = 30
# iter = 30, obj = 6.89044e+01, resnorm = 1.17e+01, gradnorm = 2.68e-02, feval = 91, geval = 31
# iter = 31, obj = 6.55017e+01, resnorm = 1.14e+01, gradnorm = 2.48e-02, feval = 94, geval = 32
# iter = 32, obj = 6.29800e+01, resnorm = 1.12e+01, gradnorm = 2.28e-02, feval = 97, geval = 33
# iter = 33, obj = 6.02989e+01, resnorm = 1.10e+01, gradnorm = 2.32e-02, feval = 100, geval = 34
# iter = 34, obj = 5.83479e+01, resnorm = 1.08e+01, gradnorm = 2.41e-02, feval = 103, geval = 35
# iter = 35, obj = 5.63071e+01, resnorm = 1.06e+01, gradnorm = 2.43e-02, feval = 106, geval = 36
# iter = 36, obj = 5.45172e+01, resnorm = 1.04e+01, gradnorm = 2.31e-02, feval = 109, geval = 37
# iter = 37, obj = 5.27144e+01, resnorm = 1.03e+01, gradnorm = 1.96e-02, feval = 112, geval = 38
# iter = 38, obj = 5.08580e+01, resnorm = 1.01e+01, gradnorm = 1.82e-02, feval = 115, geval = 39
# iter = 39, obj = 4.92021e+01, resnorm = 9.92e+00, gradnorm = 1.97e-02, feval = 118, geval = 40
# iter = 40, obj = 4.75422e+01, resnorm = 9.75e+00, gradnorm = 1.83e-02, feval = 121, geval = 41
# iter = 41, obj = 4.63449e+01, resnorm = 9.63e+00, gradnorm = 1.75e-02, feval = 124, geval = 42
# iter = 42, obj = 4.48727e+01, resnorm = 9.47e+00, gradnorm = 1.70e-02, feval = 127, geval = 43
# iter = 43, obj = 4.34463e+01, resnorm = 9.32e+00, gradnorm = 1.74e-02, feval = 130, geval = 44
# iter = 44, obj = 4.21677e+01, resnorm = 9.18e+00, gradnorm = 1.69e-02, feval = 133, geval = 45
# iter = 45, obj = 4.09598e+01, resnorm = 9.05e+00, gradnorm = 1.60e-02, feval = 136, geval = 46
# iter = 46, obj = 3.98029e+01, resnorm = 8.92e+00, gradnorm = 1.55e-02, feval = 139, geval = 47
# iter = 47, obj = 3.86942e+01, resnorm = 8.80e+00, gradnorm = 1.57e-02, feval = 142, geval = 48
# iter = 48, obj = 3.76562e+01, resnorm = 8.68e+00, gradnorm = 1.58e-02, feval = 145, geval = 49
# iter = 49, obj = 3.66917e+01, resnorm = 8.57e+00, gradnorm = 1.37e-02, feval = 148, geval = 50
# iter = 50, obj = 3.55059e+01, resnorm = 8.43e+00, gradnorm = 1.51e-02, feval = 151, geval = 51
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# CPU times: user 9min 55s, sys: 2min 57s, total: 12min 53s
# Wall time: 1min

# %% [markdown]
# ## Plot objective function as a function of iteration

# %%
obj_func = history['obj']

fig, ax = plt.subplots(1,figsize=(10,5))
ax.plot(obj_func/obj_func.max())
_ = ax.set_xlabel('iterations')
_ = ax.set_ylabel('norm objective function')
_ = ax.set_xticks(np.arange(len(obj_func)))
ax.grid()

# %% [markdown]
# ## Plot inverted model and difference w.r.t. starting model

# %%
plotting.plot_model(history['inv_mod'],
                   title='Final inverted model',
                   cbar=True,
                   sampling=(d_x,d_z),
                   cmap='viridis',
                   src_locations=srcs,
                   rec_locations=recs,
                   figsize=(8,6))

plotting.plot_model(history['inv_mod']-starting_model,
           title='Inverted model minus strating model',
           cbar=True,
           cbar_label='$\Delta v_p$',
           sampling=(d_x,d_z),
           cmap='viridis',
           src_locations=srcs,
           rec_locations=recs,
           figsize=(8,6),
           vlims=[-500,500])

# %% [markdown]
# ## Compare first and last FWI residuals

# %%
clip = np.percentile(data_obs,99)

#first residual
plotting.plot_data(history['residual'][0],
          d_t,
          src_locations=z_src,
          rec_locations=z_rec,
          clip=clip)

#final residual
plotting.plot_data(history['residual'][-1],
          d_t,
          src_locations=z_src,
          rec_locations=z_rec,
          clip=clip)
